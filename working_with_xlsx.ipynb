# %%
# !pip install openpyxl

# %%
from openpyxl import load_workbook

wb = load_workbook('Dataset_master.xlsx')

# %%
print(wb.sheetnames)
# Out:
# ['Iris Data', 'Covid_Data_new', 'Covid_data_old', 'Simple Linear Regression (Salar', 'Covid_data Multiple Linear Regr', 'RBC in Humans Polynomial Regres', 'Salary Data Support Vector regr', 'Salary Data Decision Tree Regre', 'Salary Data Random Forest Regre', 'Model Selection - Combined Cycl', 'Instagram Ads Logistic Regressi', 'Loan Distribution KNN Classific', 'Instagram Ads SVM', 'Instagram Ads Kernel SVM', 'Instagram Ads Naive Bayes', 'Instagram Ads Decision Tree', 'Instagram Ads Random Forest', 'Breast Cancer Detection Classif', 'Loan Distribution', 'KNN Credit Score Loan Data', 'Amazon.com Clusturing Model (Pr', 'Big Basket.com Cart Apriori (Pr', 'Netflix Movie Recommendation Ec', 'Upper Confidence Bound Facebook', 'Thomson Sampling Facebook Ads O', 'Zomato Review Kaggle', 'American Express User Exit Pred', 'Pokedex']

# %%
ws = wb['Iris Data']

# %%
print(ws)
# Out:
# <Worksheet "Iris Data">

# %%
for rows in ws.rows:
    for cell in rows:
        print(cell.value)

wb.close()
# Out:
# sepal_length
# sepal_width
# petal_length
# petal_width
# species
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 5.1
# 3.5
# 1.4
# 0.2
# setosa
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 4.9
# 3.0
# 1.4
# 0.2
# setosa
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 4.7
# 3.2
# 1.3
# 0.2
# setosa
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 4.6
# 3.1
# 1.5
# 0.2
# setosa
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 5.0
# 3.6
# 1.4
# 0.2
# setosa
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
